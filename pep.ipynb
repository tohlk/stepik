# %%
# ✅ Правильно: 4 пробела на уровень отступа
def example():
    if True:
        print("Hello")

# ❌ Неправильно: табы или 2 пробела
# ✅ Правильно
x = 5
y = 10
result = x + y

# ❌ Неправильно
x=5
y=10
result=x+y
# ✅ Переменные и функции: snake_case
user_name = "John"
calculate_total()

# ✅ Классы: CapitalizedCase
class UserProfile:
    pass

# ✅ Константы: UPPER_CASE
MAX_USERS = 100
API_KEY = "secret"
# ✅ Правильно: не более 79 символов
result = (very_long_variable_name + 
          another_long_variable_name)

# ❌ Неправильно: слишком длинная строка
# ✅ Правильно: логическое разделение
import os
import sys


class MyClass:
    
    def method_one(self):
        pass
    
    def method_two(self):
        pass


def standalone_function():
    pass
# ✅ Правильно: группами и отсортировано
import os
import sys

from typing import List, Dict
from collections import defaultdict

# ❌ Неправильно: все вперемешку
# ✅ Правильно: комментарии над кодом
# Проверяем, является ли число четным
if number % 2 == 0:
    print("Четное")

# ❌ Неправильно: комментарии в конце строки
if number % 2 == 0:  # Проверка на четность
def calculate_sum(a, b):
    """
    Возвращает сумму двух чисел.
    
    Args:
        a (int): Первое число
        b (int): Второе число
        
    Returns:
        int: Сумма a и b
    """
    return a + b
# ✅ Правильно
if (username == "admin" 
    and password == "secret"):
    login()

# ❌ Неправильно
if username == "admin" and password == "secret": login()
# ✅ Правильно
fruits = [
    "apple",
    "banana", 
    "orange",
]

user = {
    "name": "John",
    "age": 25,
}

# ❌ Неправильно
fruits = ["apple","banana","orange"]
# ✅ Правильно
try:
    risky_operation()
except ValueError as e:
    print(f"Ошибка: {e}")

# ❌ Неправильно
try:risky_operation()
except:pass
